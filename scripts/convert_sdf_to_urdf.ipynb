# %%
import os
import subprocess
import time

# Set the base directory where the objects are located
# base_dir = "/workspaces/panda_ws/gazebo-objects/objects_gazebo/kit"
# base_dir = "/workspaces/panda_ws/gazebo-objects/objects_gazebo/bigbird"
base_dir = "/workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb"

# Source ROS setup script
subprocess.call("source /workspaces/panda_ws/devel/setup.bash", shell=True, executable='/bin/bash')
# Out:
# 0

# %%
# Loop through all directories inside the base directory
for object_name in os.listdir(base_dir):
    object_dir = os.path.join(base_dir, object_name)
    if os.path.isdir(object_dir):
        sdf_file = os.path.join(object_dir, "{}.sdf".format(object_name))
        urdf_file = os.path.join(object_dir, "{}.urdf".format(object_name))

        if os.path.isfile(sdf_file):
            print "Processing {}".format(object_name)
            
            # Run the setup script and the rosrun command in the same subshell
            command = "source /workspaces/panda_ws/devel/setup.bash && rosrun pysdf sdf2urdf.py {} {}".format(sdf_file, urdf_file)
            subprocess.call(command, shell=True, executable='/bin/bash')

            # After the URDF is generated, replace 'package://PATHTOMESHES/ObjectName' with '.'
            if os.path.isfile(urdf_file):
                print "Modifying URDF {}".format(urdf_file)

                # Read the contents of the URDF file
                with open(urdf_file, 'r') as file:
                    filedata = file.read()

                # Replace 'package://PATHTOMESHES/ObjectName' with '.'
                old_string = "package://PATHTOMESHES/{}".format(object_name)
                newdata = filedata.replace(old_string, ".")

                # Write the modified data back to the URDF file
                with open(urdf_file, 'w') as file:
                    file.write(newdata)

                print "Replaced '{}' with '.' in {}".format(old_string, urdf_file)
            else:
                print "URDF file not found for {}".format(object_name)
        else:
            print "SDF file not found for {}".format(object_name)
# Out:
# Processing 011_banana
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/011_banana/011_banana.urdf
# Replaced 'package://PATHTOMESHES/011_banana' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/011_banana/011_banana.urdf
# Processing 042_adjustable_wrench
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/042_adjustable_wrench/042_adjustable_wrench.urdf
# Replaced 'package://PATHTOMESHES/042_adjustable_wrench' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/042_adjustable_wrench/042_adjustable_wrench.urdf
# Processing 073-j_lego_duplo
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-j_lego_duplo/073-j_lego_duplo.urdf
# Replaced 'package://PATHTOMESHES/073-j_lego_duplo' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-j_lego_duplo/073-j_lego_duplo.urdf
# Processing 032_knife
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/032_knife/032_knife.urdf
# Replaced 'package://PATHTOMESHES/032_knife' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/032_knife/032_knife.urdf
# Processing 003_cracker_box
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/003_cracker_box/003_cracker_box.urdf
# Replaced 'package://PATHTOMESHES/003_cracker_box' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/003_cracker_box/003_cracker_box.urdf
# Processing 070-a_colored_wood_blocks
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/070-a_colored_wood_blocks/070-a_colored_wood_blocks.urdf
# Replaced 'package://PATHTOMESHES/070-a_colored_wood_blocks' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/070-a_colored_wood_blocks/070-a_colored_wood_blocks.urdf
# Processing 051_large_clamp
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/051_large_clamp/051_large_clamp.urdf
# Replaced 'package://PATHTOMESHES/051_large_clamp' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/051_large_clamp/051_large_clamp.urdf
# Processing 044_flat_screwdriver
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/044_flat_screwdriver/044_flat_screwdriver.urdf
# Replaced 'package://PATHTOMESHES/044_flat_screwdriver' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/044_flat_screwdriver/044_flat_screwdriver.urdf
# Processing 065-i_cups
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-i_cups/065-i_cups.urdf
# Replaced 'package://PATHTOMESHES/065-i_cups' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-i_cups/065-i_cups.urdf
# Processing 073-g_lego_duplo
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-g_lego_duplo/073-g_lego_duplo.urdf
# Replaced 'package://PATHTOMESHES/073-g_lego_duplo' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-g_lego_duplo/073-g_lego_duplo.urdf
# Processing 056_tennis_ball
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/056_tennis_ball/056_tennis_ball.urdf
# Replaced 'package://PATHTOMESHES/056_tennis_ball' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/056_tennis_ball/056_tennis_ball.urdf
# Processing 057_racquetball
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/057_racquetball/057_racquetball.urdf
# Replaced 'package://PATHTOMESHES/057_racquetball' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/057_racquetball/057_racquetball.urdf
# Processing 065-c_cups
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-c_cups/065-c_cups.urdf
# Replaced 'package://PATHTOMESHES/065-c_cups' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-c_cups/065-c_cups.urdf
# Processing 072-f_toy_airplane
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-f_toy_airplane/072-f_toy_airplane.urdf
# Replaced 'package://PATHTOMESHES/072-f_toy_airplane' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-f_toy_airplane/072-f_toy_airplane.urdf
# Processing 017_orange
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/017_orange/017_orange.urdf
# Replaced 'package://PATHTOMESHES/017_orange' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/017_orange/017_orange.urdf
# Processing 070-b_colored_wood_blocks
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/070-b_colored_wood_blocks/070-b_colored_wood_blocks.urdf
# Replaced 'package://PATHTOMESHES/070-b_colored_wood_blocks' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/070-b_colored_wood_blocks/070-b_colored_wood_blocks.urdf
# Processing 005_tomato_soup_can
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/005_tomato_soup_can/005_tomato_soup_can.urdf
# Replaced 'package://PATHTOMESHES/005_tomato_soup_can' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/005_tomato_soup_can/005_tomato_soup_can.urdf
# Processing 065-f_cups
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-f_cups/065-f_cups.urdf
# Replaced 'package://PATHTOMESHES/065-f_cups' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-f_cups/065-f_cups.urdf
# Processing 065-h_cups
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-h_cups/065-h_cups.urdf
# Replaced 'package://PATHTOMESHES/065-h_cups' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-h_cups/065-h_cups.urdf
# Processing 072-d_toy_airplane
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-d_toy_airplane/072-d_toy_airplane.urdf
# Replaced 'package://PATHTOMESHES/072-d_toy_airplane' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-d_toy_airplane/072-d_toy_airplane.urdf
# Processing 037_scissors
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/037_scissors/037_scissors.urdf
# Replaced 'package://PATHTOMESHES/037_scissors' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/037_scissors/037_scissors.urdf
# Processing 004_sugar_box
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/004_sugar_box/004_sugar_box.urdf
# Replaced 'package://PATHTOMESHES/004_sugar_box' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/004_sugar_box/004_sugar_box.urdf
# Processing 012_strawberry
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/012_strawberry/012_strawberry.urdf
# Replaced 'package://PATHTOMESHES/012_strawberry' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/012_strawberry/012_strawberry.urdf
# Processing 041_small_marker
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/041_small_marker/041_small_marker.urdf
# Replaced 'package://PATHTOMESHES/041_small_marker' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/041_small_marker/041_small_marker.urdf
# Processing 023_wine_glass
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/023_wine_glass/023_wine_glass.urdf
# Replaced 'package://PATHTOMESHES/023_wine_glass' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/023_wine_glass/023_wine_glass.urdf
# Processing 008_pudding_box
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/008_pudding_box/008_pudding_box.urdf
# Replaced 'package://PATHTOMESHES/008_pudding_box' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/008_pudding_box/008_pudding_box.urdf
# Processing 058_golf_ball
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/058_golf_ball/058_golf_ball.urdf
# Replaced 'package://PATHTOMESHES/058_golf_ball' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/058_golf_ball/058_golf_ball.urdf
# Processing 026_sponge
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/026_sponge/026_sponge.urdf
# Replaced 'package://PATHTOMESHES/026_sponge' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/026_sponge/026_sponge.urdf
# Processing 010_potted_meat_can
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/010_potted_meat_can/010_potted_meat_can.urdf
# Replaced 'package://PATHTOMESHES/010_potted_meat_can' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/010_potted_meat_can/010_potted_meat_can.urdf
# Processing 077_rubiks_cube
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/077_rubiks_cube/077_rubiks_cube.urdf
# Replaced 'package://PATHTOMESHES/077_rubiks_cube' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/077_rubiks_cube/077_rubiks_cube.urdf
# Processing 036_wood_block
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/036_wood_block/036_wood_block.urdf
# Replaced 'package://PATHTOMESHES/036_wood_block' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/036_wood_block/036_wood_block.urdf
# Processing 072-j_toy_airplane
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-j_toy_airplane/072-j_toy_airplane.urdf
# Replaced 'package://PATHTOMESHES/072-j_toy_airplane' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-j_toy_airplane/072-j_toy_airplane.urdf
# Processing 031_spoon
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/031_spoon/031_spoon.urdf
# Replaced 'package://PATHTOMESHES/031_spoon' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/031_spoon/031_spoon.urdf
# Processing 072-c_toy_airplane
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-c_toy_airplane/072-c_toy_airplane.urdf
# Replaced 'package://PATHTOMESHES/072-c_toy_airplane' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-c_toy_airplane/072-c_toy_airplane.urdf
# Processing 072-b_toy_airplane
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-b_toy_airplane/072-b_toy_airplane.urdf
# Replaced 'package://PATHTOMESHES/072-b_toy_airplane' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-b_toy_airplane/072-b_toy_airplane.urdf
# Processing 002_master_chef_can
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/002_master_chef_can/002_master_chef_can.urdf
# Replaced 'package://PATHTOMESHES/002_master_chef_can' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/002_master_chef_can/002_master_chef_can.urdf
# Processing 072-k_toy_airplane
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-k_toy_airplane/072-k_toy_airplane.urdf
# Replaced 'package://PATHTOMESHES/072-k_toy_airplane' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-k_toy_airplane/072-k_toy_airplane.urdf
# Processing 015_peach
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/015_peach/015_peach.urdf
# Replaced 'package://PATHTOMESHES/015_peach' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/015_peach/015_peach.urdf
# Processing 024_bowl
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/024_bowl/024_bowl.urdf
# Replaced 'package://PATHTOMESHES/024_bowl' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/024_bowl/024_bowl.urdf
# Processing 029_plate
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/029_plate/029_plate.urdf
# Replaced 'package://PATHTOMESHES/029_plate' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/029_plate/029_plate.urdf
# Processing 016_pear
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/016_pear/016_pear.urdf
# Replaced 'package://PATHTOMESHES/016_pear' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/016_pear/016_pear.urdf
# Processing 073-d_lego_duplo
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-d_lego_duplo/073-d_lego_duplo.urdf
# Replaced 'package://PATHTOMESHES/073-d_lego_duplo' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-d_lego_duplo/073-d_lego_duplo.urdf
# Processing 052_extra_large_clamp
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/052_extra_large_clamp/052_extra_large_clamp.urdf
# Replaced 'package://PATHTOMESHES/052_extra_large_clamp' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/052_extra_large_clamp/052_extra_large_clamp.urdf
# Processing 050_medium_clamp
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/050_medium_clamp/050_medium_clamp.urdf
# Replaced 'package://PATHTOMESHES/050_medium_clamp' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/050_medium_clamp/050_medium_clamp.urdf
# Processing 006_mustard_bottle
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/006_mustard_bottle/006_mustard_bottle.urdf
# Replaced 'package://PATHTOMESHES/006_mustard_bottle' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/006_mustard_bottle/006_mustard_bottle.urdf
# Processing 054_softball
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/054_softball/054_softball.urdf
# Replaced 'package://PATHTOMESHES/054_softball' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/054_softball/054_softball.urdf
# Processing 009_gelatin_box
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/009_gelatin_box/009_gelatin_box.urdf
# Replaced 'package://PATHTOMESHES/009_gelatin_box' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/009_gelatin_box/009_gelatin_box.urdf
# Processing 059_chain
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/059_chain/059_chain.urdf
# Replaced 'package://PATHTOMESHES/059_chain' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/059_chain/059_chain.urdf
# Processing 025_mug
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/025_mug/025_mug.urdf
# Replaced 'package://PATHTOMESHES/025_mug' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/025_mug/025_mug.urdf
# Processing 019_pitcher_base
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/019_pitcher_base/019_pitcher_base.urdf
# Replaced 'package://PATHTOMESHES/019_pitcher_base' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/019_pitcher_base/019_pitcher_base.urdf
# Processing 065-e_cups
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-e_cups/065-e_cups.urdf
# Replaced 'package://PATHTOMESHES/065-e_cups' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-e_cups/065-e_cups.urdf
# Processing 028_skillet_lid
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/028_skillet_lid/028_skillet_lid.urdf
# Replaced 'package://PATHTOMESHES/028_skillet_lid' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/028_skillet_lid/028_skillet_lid.urdf
# Processing 055_baseball
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/055_baseball/055_baseball.urdf
# Replaced 'package://PATHTOMESHES/055_baseball' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/055_baseball/055_baseball.urdf
# Processing 073-m_lego_duplo
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-m_lego_duplo/073-m_lego_duplo.urdf
# Replaced 'package://PATHTOMESHES/073-m_lego_duplo' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-m_lego_duplo/073-m_lego_duplo.urdf
# Processing 021_bleach_cleanser
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/021_bleach_cleanser/021_bleach_cleanser.urdf
# Replaced 'package://PATHTOMESHES/021_bleach_cleanser' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/021_bleach_cleanser/021_bleach_cleanser.urdf
# Processing 073-a_lego_duplo
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-a_lego_duplo/073-a_lego_duplo.urdf
# Replaced 'package://PATHTOMESHES/073-a_lego_duplo' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-a_lego_duplo/073-a_lego_duplo.urdf
# Processing 065-b_cups
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-b_cups/065-b_cups.urdf
# Replaced 'package://PATHTOMESHES/065-b_cups' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-b_cups/065-b_cups.urdf
# Processing 033_spatula
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/033_spatula/033_spatula.urdf
# Replaced 'package://PATHTOMESHES/033_spatula' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/033_spatula/033_spatula.urdf
# Processing 040_large_marker
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/040_large_marker/040_large_marker.urdf
# Replaced 'package://PATHTOMESHES/040_large_marker' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/040_large_marker/040_large_marker.urdf
# Processing 062_dice
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/062_dice/062_dice.urdf
# Replaced 'package://PATHTOMESHES/062_dice' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/062_dice/062_dice.urdf
# Processing 073-b_lego_duplo
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-b_lego_duplo/073-b_lego_duplo.urdf
# Replaced 'package://PATHTOMESHES/073-b_lego_duplo' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-b_lego_duplo/073-b_lego_duplo.urdf
# Processing 049_small_clamp
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/049_small_clamp/049_small_clamp.urdf
# Replaced 'package://PATHTOMESHES/049_small_clamp' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/049_small_clamp/049_small_clamp.urdf
# Processing 065-g_cups
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-g_cups/065-g_cups.urdf
# Replaced 'package://PATHTOMESHES/065-g_cups' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-g_cups/065-g_cups.urdf
# Processing 043_phillips_screwdriver
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/043_phillips_screwdriver/043_phillips_screwdriver.urdf
# Replaced 'package://PATHTOMESHES/043_phillips_screwdriver' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/043_phillips_screwdriver/043_phillips_screwdriver.urdf
# Processing 072-i_toy_airplane
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-i_toy_airplane/072-i_toy_airplane.urdf
# Replaced 'package://PATHTOMESHES/072-i_toy_airplane' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-i_toy_airplane/072-i_toy_airplane.urdf
# Processing 073-k_lego_duplo
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-k_lego_duplo/073-k_lego_duplo.urdf
# Replaced 'package://PATHTOMESHES/073-k_lego_duplo' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-k_lego_duplo/073-k_lego_duplo.urdf
# Processing 035_power_drill
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/035_power_drill/035_power_drill.urdf
# Replaced 'package://PATHTOMESHES/035_power_drill' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/035_power_drill/035_power_drill.urdf
# Processing 061_foam_brick
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/061_foam_brick/061_foam_brick.urdf
# Replaced 'package://PATHTOMESHES/061_foam_brick' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/061_foam_brick/061_foam_brick.urdf
# Processing 072-h_toy_airplane
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-h_toy_airplane/072-h_toy_airplane.urdf
# Replaced 'package://PATHTOMESHES/072-h_toy_airplane' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-h_toy_airplane/072-h_toy_airplane.urdf
# Processing 065-d_cups
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-d_cups/065-d_cups.urdf
# Replaced 'package://PATHTOMESHES/065-d_cups' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-d_cups/065-d_cups.urdf
# Processing 018_plum
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/018_plum/018_plum.urdf
# Replaced 'package://PATHTOMESHES/018_plum' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/018_plum/018_plum.urdf
# Processing 065-a_cups
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-a_cups/065-a_cups.urdf
# Replaced 'package://PATHTOMESHES/065-a_cups' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/065-a_cups/065-a_cups.urdf
# Processing 073-i_lego_duplo
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-i_lego_duplo/073-i_lego_duplo.urdf
# Replaced 'package://PATHTOMESHES/073-i_lego_duplo' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-i_lego_duplo/073-i_lego_duplo.urdf
# Processing 073-e_lego_duplo
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-e_lego_duplo/073-e_lego_duplo.urdf
# Replaced 'package://PATHTOMESHES/073-e_lego_duplo' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-e_lego_duplo/073-e_lego_duplo.urdf
# Processing 053_mini_soccer_ball
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/053_mini_soccer_ball/053_mini_soccer_ball.urdf
# Replaced 'package://PATHTOMESHES/053_mini_soccer_ball' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/053_mini_soccer_ball/053_mini_soccer_ball.urdf
# Processing 001_chips_can
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/001_chips_can/001_chips_can.urdf
# Replaced 'package://PATHTOMESHES/001_chips_can' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/001_chips_can/001_chips_can.urdf
# Processing 073-f_lego_duplo
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-f_lego_duplo/073-f_lego_duplo.urdf
# Replaced 'package://PATHTOMESHES/073-f_lego_duplo' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-f_lego_duplo/073-f_lego_duplo.urdf
# Processing 048_hammer
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/048_hammer/048_hammer.urdf
# Replaced 'package://PATHTOMESHES/048_hammer' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/048_hammer/048_hammer.urdf
# Processing 072-e_toy_airplane
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-e_toy_airplane/072-e_toy_airplane.urdf
# Replaced 'package://PATHTOMESHES/072-e_toy_airplane' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-e_toy_airplane/072-e_toy_airplane.urdf
# Processing 014_lemon
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/014_lemon/014_lemon.urdf
# Replaced 'package://PATHTOMESHES/014_lemon' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/014_lemon/014_lemon.urdf
# Processing 022_windex_bottle
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/022_windex_bottle/022_windex_bottle.urdf
# Replaced 'package://PATHTOMESHES/022_windex_bottle' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/022_windex_bottle/022_windex_bottle.urdf
# Processing 038_padlock
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/038_padlock/038_padlock.urdf
# Replaced 'package://PATHTOMESHES/038_padlock' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/038_padlock/038_padlock.urdf
# Processing 072-a_toy_airplane
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-a_toy_airplane/072-a_toy_airplane.urdf
# Replaced 'package://PATHTOMESHES/072-a_toy_airplane' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/072-a_toy_airplane/072-a_toy_airplane.urdf
# Processing 013_apple
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/013_apple/013_apple.urdf
# Replaced 'package://PATHTOMESHES/013_apple' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/013_apple/013_apple.urdf
# Processing 007_tuna_fish_can
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/007_tuna_fish_can/007_tuna_fish_can.urdf
# Replaced 'package://PATHTOMESHES/007_tuna_fish_can' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/007_tuna_fish_can/007_tuna_fish_can.urdf
# Processing 071_nine_hole_peg_test
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/071_nine_hole_peg_test/071_nine_hole_peg_test.urdf
# Replaced 'package://PATHTOMESHES/071_nine_hole_peg_test' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/071_nine_hole_peg_test/071_nine_hole_peg_test.urdf
# Processing 073-h_lego_duplo
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-h_lego_duplo/073-h_lego_duplo.urdf
# Replaced 'package://PATHTOMESHES/073-h_lego_duplo' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-h_lego_duplo/073-h_lego_duplo.urdf
# Processing 073-c_lego_duplo
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-c_lego_duplo/073-c_lego_duplo.urdf
# Replaced 'package://PATHTOMESHES/073-c_lego_duplo' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-c_lego_duplo/073-c_lego_duplo.urdf
# Processing 030_fork
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/030_fork/030_fork.urdf
# Replaced 'package://PATHTOMESHES/030_fork' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/030_fork/030_fork.urdf
# Processing 073-l_lego_duplo
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-l_lego_duplo/073-l_lego_duplo.urdf
# Replaced 'package://PATHTOMESHES/073-l_lego_duplo' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/073-l_lego_duplo/073-l_lego_duplo.urdf
# Processing 076_timer
# Modifying URDF /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/076_timer/076_timer.urdf
# Replaced 'package://PATHTOMESHES/076_timer' with '.' in /workspaces/panda_ws/gazebo-objects/objects_gazebo/ycb/076_timer/076_timer.urdf
